# %%
import boto3
import pandas as pd
from io import StringIO,BytesIO # to read csv using s3 storage
from datetime import datetime, timedelta 
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient

# %%
arg_date = '2022-12-29'
az_des_con_str = 'DefaultEndpointsProtocol=https;AccountName=xetradestination;AccountKey=jHuTzDSICJbvjv/YKkQescXmPJg8Gntu/U1/P36fXqssoTAjPj7LCyo/lj1tTcjeSBaoY2IzFyKe+AStvRyTtQ==;EndpointSuffix=core.windows.net'

# %%
arg_date_dt = datetime.strptime(arg_date, '%Y-%m-%d').date() - timedelta(days=1)

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('xetra-1234')
objects = [obj for obj in bucket.objects.all() if datetime.strptime(str(obj.key).split('/')[0], '%Y-%m-%d').date() >= arg_date_dt]

# %%
df_all = pd.DataFrame()
ls = []
for obj in objects:
    csv_obj = bucket.Object(key=obj.key).get().get('Body').read().decode('utf-8')
    data = StringIO(csv_obj)
    df = pd.read_csv(data, delimiter=',')
    ls.append(df)
df_all = pd.concat(ls,ignore_index=True)
len(df_all)
# Out:
# 263838

# %%
cols_needed = ['ISIN', 'Date', 'Time', 'StartPrice', 'MaxPrice', 'MinPrice','EndPrice', 'TradedVolume', 'NumberOfTrades']
df_all = df_all.loc[:,cols_needed]

# %%
df_all.dropna(inplace=True)

# %% [markdown]
# ## Get opening price for ISIN per date.

# %%
df_all['opening_price'] = df_all.sort_values(by=['Time']).groupby(['ISIN','Date'])['StartPrice'].transform('first')

# %% [markdown]
# ## Closing Price For ISIN

# %%
df_all['closing_price'] = df_all.sort_values(by=['Time']).groupby(['ISIN','Date'])['StartPrice'].transform('last')

# %%
df_all= df_all.groupby(['ISIN','Date'], as_index=True)

# %%
df_all = df_all.agg(opening_price_euro=('opening_price','min'), closing_price_euro=('closing_price','min'), minimum_price_euro=('MinPrice','min'), maxmimum_price_euro=('MaxPrice','max'), daily_traded_volume=('TradedVolume','sum') )

# %% [markdown]
# # Prev - Pres Closing Price

# %%
df_all['prev_closing_price'] = df_all.sort_values(by=['Date']).groupby(['ISIN'])['closing_price_euro'].shift(1)

# %%
df_all['change_prev_closing_precent'] = (df_all['closing_price_euro'] - df_all['prev_closing_price']) / df_all['prev_closing_price'] * 100

# %%
df_all.drop(columns=['closing_price_euro'], inplace=True)

# %%
df_all = df_all.round(decimals=2)

# %%
df_all
# Out:
#                          opening_price_euro  minimum_price_euro  \
# ISIN         Date
# AT000000STR1 2022-12-28               36.60               35.75
#              2022-12-29               36.60               35.75
# AT00000FACC2 2022-12-28                8.05                7.87
#              2022-12-29                8.05                7.87
# AT0000606306 2022-12-28               14.51               13.65
# ...                                     ...                 ...
# XS2314660700 2022-12-29               22.26               21.92
# XS2376095068 2022-12-28               34.29               34.06
#              2022-12-29               34.29               34.06
# XS2434891219 2022-12-28                3.44                3.42
#              2022-12-29                3.44                3.42
#
#                          maxmimum_price_euro daily_traded_volume  \
# ISIN         Date
# AT000000STR1 2022-12-28                36.70                1773
# ...

# %% [markdown]
# ## AWS Write to Bucket xetra-destination

# %%
keys = ['parquet/xetra_daily_report_'+datetime.today().strftime('%y%m%d_%H%M%S')+'.parquet','csv/xetra_daily_report_'+datetime.today().strftime('%y%m%d_%H%M%S') + '.parquet']

# %%
output_buffer = BytesIO()

# %%
df_all.to_parquet(output_buffer, index=False)

# %%
bucket_target = s3.Bucket('xetra-destination')

# %%
for i in keys:
    print(output_buffer.getvalue())
    print("***********************************************************************one***********************************************************************")
    bucket_target.put_object(Body=output_buffer.getvalue(),Key=i)
# Out:
# b'PAR1\x15\x04\x15\xa0\xd3\x02\x15\xd8\xc7\x01L\x15\xb4*\x15\x00\x12\x00\x00\xd0\xa9\x01|\xcd\xcc\xcc\xcc\xccLB@\x9a\x99\x99\x99\x99\x19 @\x85\xebQ\xb8\x1e\x05-@{\x14\xaeG\xe1z\'@\x05 ,\x8cX@\xf6(\\\x8f\xc2\x15@@3\x01\x01(\xb36@)\\\x8f\xc2\xf5(D@\x01&\x10\x14.F@\x00\x05\x01\x08Z@f\x05\x01\x00=\t(\x04s;\t\x08\x083\x1d@\x05O$\x14\xee?R\xb8\x1e\x85\xeb\xd1:\r\x10\x00 \tx\x04\xd9D\t8\x04\xe6<\t0\x04\xd3d\tP\x04\xe0B\t\x80$\xecG@H\xe1z\x14\xaeG\x1c\t \x103\xff?\xc3\xf5\x01\x91\x00+\tH\x04\x94+\tH\x04\x991\t0$\x0cB@=\n\xd7\xa3p=G\tH\x04\x00T\t\xa8\x04\xae0\t \x04L;\r\xc0\x00\x16\t \x08`M@\x01\x97\x08QXE\t\x88\x04f\x18\r\x08\x00L\t\x18\x04\xf8A\t(\x08\x00\xe0?\tX\x04\xea?\x050\x08\xb8\xf2?\x01f\x0c\n\xd7\xeb?%\x08\x10\xae\xe7?\xecQ\x01\x1a\x04\xfd?)@\x0c\xe4?\xa4p\x012\x04\xf8?\t\xc0\x04\xe9?\x05\xc7\x08\xe1\xf2?%/\x04\x00\xf0\r@\x04\xe3?!W\x0833!\tx\x08&4@\t\xe0\x0c\x17@\x1f\x85!\x91\x08\xf1?q\x01G\x04\xf0"\r\xe8\x00\x1b)\x08\x04\xd3z\r\x10\x00$)\xb8\x04\x85\x13\r\xa8\x00R\t\x08\x08\xc01@\
# ...

# %% [markdown]
# ## Read the uploaded file

# %%
for obj in bucket_target.objects.all():
    print(obj.key)
    parquet_obj = bucket_target.Object(key=obj.key).get().get('Body').read()#.decode('utf-8')
    data = BytesIO(parquet_obj)
    df_report = pd.read_parquet(data)
# Out:
# csv/xetra_daily_report_221229_191937.parquet
# parquet/xetra_daily_report_221229_191937.parquet

# %% [markdown]
# ## AZURE Write to Container xetra-destination

# %%
blob_service_client = BlobServiceClient.from_connection_string(az_des_con_str)

# %%
container_client=blob_service_client.get_container_client('xetra-destination')

# %%
for i in keys:
    blob_client = blob_service_client.get_blob_client(container='xetra-destination', blob=i)
    print(data)
    print("***********************************************************************one***********************************************************************")
    blob_client.upload_blob(data)
# Out:
# ...
# ***********************************************************************one***********************************************************************
# ...
# ***********************************************************************one***********************************************************************

# %%
blob_list = container_client.list_blobs()
for blob in blob_list:
    print(container_client.download_blob(blob.name).readall())
# Out:
# b''
# b''
# ...
